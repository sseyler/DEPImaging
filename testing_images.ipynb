# %%
from skimage import data
import matplotlib.pyplot as plt

# %%
data.
# Out:
# <module 'skimage.data' from 'C:\\Users\\Sean L Seyler\\Projects\\idep_particle_flux\\env\\lib\\site-packages\\skimage\\data\\__init__.py'>

# %%
camera = data.camera()

# %%
camera
# Out:
# array([[200, 200, 200, ..., 189, 190, 190],
#        [200, 199, 199, ..., 190, 190, 190],
#        [199, 199, 199, ..., 190, 190, 190],
#        ...,
#        [ 25,  25,  27, ..., 139, 122, 147],
#        [ 25,  25,  26, ..., 158, 141, 168],
#        [ 25,  25,  27, ..., 151, 152, 149]], dtype=uint8)

# %%
type(camera)
# Out:
# numpy.ndarray

# %%
camera.shape
# Out:
# (512, 512)

# %%
plt.imshow(camera)

# %%
plt.imshow(camera, cmap='Greys')
